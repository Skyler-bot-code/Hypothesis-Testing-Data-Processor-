# %% [markdown]
# <a href="https://colab.research.google.com/github/Skyler-bot-code/Hypothesis-Testing-Data-Processor-/blob/main/One_Way_ANOVA_test_Pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# One Way ANOVA Test using Scipy

# %%
import scipy.stats as stats

# define the data set for each group

x1 = [column_1 data] # column 1
x2 = [column_2 data] # column 2
x3 = [column_3 data] # column 3
x4 = [column_4 data] # column 4

# Perform One-way ANOVA

stats.f_oneway(x1, x2, x3, x4)
